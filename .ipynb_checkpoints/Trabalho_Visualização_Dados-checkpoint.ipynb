# %% [markdown]
# TRABALHO DE VISUALIZAÇÃO DE DADOS
#
# . APRESENTAÇÃO DA EQUIPE
#
# . APRESENTAÇÃO DO DATASET UITILIZADO
#
# . DESCREVENDO O PROBLEMA Ex.: O Rank dos 10 melhores países por produto
#
# . DESCREVENDO A SOLUÇÃO
# 	- Comparação
# 	- Relacionamento
# 	- Distribuição
# 	- Composição
#
# 	Implementar todos os gráficos ensinados na aula, porém apresentar apenas o que melhor se encaixa na solução.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from os import listdir
from os.path import isfile, join

# %%
files = [f for f in listdir(os.getcwd()) if isfile(join(os.getcwd(), f))]
files
# Out:
# ['.gitattributes',
#  'datatran2007.csv',
#  'datatran2008.csv',
#  'datatran2009.csv',
#  'datatran2010.csv',
#  'datatran2011.csv',
#  'datatran2012.csv',
#  'datatran2013.csv',
#  'datatran2014.csv',
#  'datatran2015.csv',
#  'datatran2016.csv',
#  'datatran2017.csv',
#  'datatran2018.csv',
#  'datatran2019.csv',
#  'datatran2020.csv',
#  'LICENSE',
#  'README.md',
#  'Trabalho_Visualização_Dados.ipynb']

# %% [markdown]
# ### 2007

# %%
df_2007 = pd.read_csv("datatran2007.csv", sep=';', low_memory=False)

# %%
df_2007 = df_2007[df_2007['municipio'] == 'MANAUS'].copy()

# %%
df_2007.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2007.head()
# Out:
#      data_inversa dia_semana   br    km    causa_acidente     tipo_acidente  \
# 1112   02/01/2007      Terça  174   9.3  Falta de atenção    Saída de Pista
# 1145   02/01/2007      Terça  174   7.9            Outras  Colisão traseira
# 1964   07/01/2007    Domingo  174  52.1    Defeito na via       Capotamento
# 2931   11/01/2007     Quinta  174  85.8            Outras          Incêndio
# 5475   19/01/2007      Sexta  174   3.3  Falta de atenção   Colisão lateral
#
#        fase_dia condicao_metereologica  mortos  ilesos  feridos
# 1112  Pleno dia                  Chuva       0       0        1
# 1145  Anoitecer                  Chuva       0       4        0
# 1964  Pleno dia                    Sol       0       0        2
# 2931  Anoitecer       Nevoeiro/neblina       0       1        0
# 5475  Pleno dia              Ceu Claro       0       2        0

# %% [markdown]
# ### 2008

# %%
df_2008 = pd.read_csv("datatran2008.csv", sep=';', low_memory=False)

# %%
df_2008 = df_2008[df_2008['municipio'] == 'MANAUS'].copy()

# %%
df_2008.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2008.head()
# Out:
#      data_inversa dia_semana   br  km           causa_acidente  \
# 1213   05/01/2008     Sábado  174  50                   Outras
# 4667   11/01/2008      Sexta  174  28                   Outras
# 5954   18/01/2008      Sexta  174  61         Falta de atenção
# 7432   20/01/2008    Domingo  174  30                   Outras
# 8295   24/01/2008     Quinta  174  78  Velocidade incompatível
#
#                 tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 1213           Saída de Pista    Pleno dia                  Chuva       0
# 4667           Saída de Pista    Pleno dia                Nublado       0
# 5954           Saída de Pista    Pleno dia                  Chuva       0
# 7432  Atropelamento de pessoa  Plena noite              Ceu Claro       0
# 8295         Colisão traseira    Pleno dia              Ceu Claro       0
#
#       ilesos  feridos
# 1213       1        0
# 4667       2        0
# 5954       1        1
# 7432       1        1
# 8295       3        0

# %% [markdown]
# ### 2009

# %%
df_2009 = pd.read_csv("datatran2009.csv", sep=';', low_memory=False)

# %%
df_2009 = df_2009[df_2009['municipio'] == 'MANAUS'].copy()

# %%
df_2009.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2009.head()
# Out:
#      data_inversa dia_semana   br     km                      causa_acidente  \
# 375    02/01/2009      Sexta  174   47.3                              Outras
# 1340   04/01/2009    Domingo  319    1.0                              Outras
# 1448   04/01/2009    Domingo  174   10.0  Não guardar distância de segurança
# 2742   05/01/2009    Segunda  174   73.8                              Outras
# 3660   11/01/2009    Domingo  174  123.5                      Defeito na via
#
#                 tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 375            Saída de Pista    Pleno dia              Ceu Claro       0
# 1340  Colisão com objeto fixo    Pleno dia                    Sol       0
# 1448         Colisão traseira    Pleno dia                Nublado       0
# 2742  Atropelamento de pessoa  Plena noite              Ceu Claro       1
# 3660           Saída de Pista    Pleno dia              Ceu Claro       0
#
#       ilesos  feridos
# 375        4        1
# ...

# %% [markdown]
# ### 2010

# %%
df_2010 = pd.read_csv("datatran2010.csv", sep=';', low_memory=False)

# %%
df_2010 = df_2010[df_2010['municipio'] == 'MANAUS'].copy()

# %%
df_2010.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2010.head()
# Out:
#      data_inversa dia_semana   br    km                      causa_acidente  \
# 521    02/01/2010     Sábado  174   2.3  Não guardar distância de segurança
# 564    02/01/2010     Sábado  174   3.0                    Falta de atenção
# 1597   03/01/2010    Domingo  174  16.2                            Dormindo
# 2291   06/01/2010     Quarta  174  83.4                    Falta de atenção
# 5703   14/01/2010     Quinta  174  75.0                              Outras
#
#             tipo_acidente     fase_dia condicao_metereologica  mortos  ilesos  \
# 521      Colisão traseira    Pleno dia              Ceu Claro       0      21
# 564   Colisão Transversal    Pleno dia              Ceu Claro       0       8
# 1597       Saída de Pista  Plena noite                Nublado       0       1
# 2291       Saída de Pista  Plena noite              Ceu Claro       0       2
# 5703     Colisão traseira    Anoitecer              Ceu Claro       0       2
#
#       feridos
# 521         0
# ...

# %% [markdown]
# ## 2011

# %%
df_2011 = pd.read_csv("datatran2011.csv", sep=';', low_memory=False)

# %%
df_2011 = df_2011[df_2011['municipio'] == 'MANAUS'].copy()

# %%
df_2011.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2011.head()
# Out:
#      data_inversa dia_semana   br    km           causa_acidente  \
# 299    29/10/2011     Sábado  174  89.8         Falta de atenção
# 1109   29/10/2011     Sábado  174   2.7   Ultrapassagem indevida
# 1573   01/11/2011      Terça  174  10.7  Velocidade incompatível
# 2060   02/11/2011     Quarta  174  67.7                   Outras
# 2667   03/11/2011     Quinta  174  14.8                   Outras
#
#             tipo_acidente   fase_dia condicao_metereologica  mortos  ilesos  \
# 299        Saída de Pista  Pleno dia                    Sol       0       4
# 1109      Colisão frontal  Pleno dia              Ceu Claro       0       1
# 1573  Colisão Transversal  Pleno dia                  Chuva       0       2
# 2060      Colisão frontal  Pleno dia                Nublado       0       5
# 2667       Saída de Pista  Pleno dia                  Chuva       0       1
#
#       feridos
# 299         1
# 1109        5
# 1573        0
# 2060        0
# 2667        0

# %% [markdown]
# ## 2012

# %%
df_2012 = pd.read_csv("datatran2012.csv", sep=';', low_memory=False)

# %%
df_2012 = df_2012[df_2012['municipio'] == 'MANAUS'].copy()

# %%
df_2012.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2012.head()
# Out:
#      data_inversa dia_semana   br     km                      causa_acidente  \
# 204    2012-01-01    Domingo  174   23.9                    Animais na Pista
# 2772   2012-01-03      Terça  174   62.1                            Dormindo
# 4587   2012-01-11     Quarta  319    0.8  Não guardar distância de segurança
# 6357   2012-01-07     Sábado  174  166.6                            Dormindo
# 7341   2012-01-16    Segunda  174    9.3                    Falta de atenção
#
#                 tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 204   Atropelamento de animal  Plena noite              Ceu Claro       0
# 2772           Saída de Pista    Anoitecer                Nublado       0
# 4587         Colisão traseira    Pleno dia              Ceu Claro       0
# 6357           Saída de Pista    Pleno dia                Nublado       1
# 7341           Saída de Pista    Pleno dia                  Chuva       0
#
#       ilesos  feridos
# 204        1        1
# ...

# %% [markdown]
# ## 2013

# %%
df_2013 = pd.read_csv("datatran2013.csv", sep=';', low_memory=False)

# %%
df_2013 = df_2013[df_2013['municipio'] == 'MANAUS'].copy()

# %%
df_2013.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2013.head()
# Out:
#      data_inversa dia_semana   br    km           causa_acidente  \
# 270    2013-01-01      Terça  174  46.0                   Outras
# 669    2013-01-02     Quarta  174  25.0                   Outras
# 3966   2013-01-10     Quinta  174  39.0                 Dormindo
# 6878   2013-01-14    Segunda  174  21.0                   Outras
# 9032   2013-01-20    Domingo  174  53.0  Velocidade incompatível
#
#                 tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 270            Saída de Pista    Pleno dia                  Chuva       0
# 669            Saída de Pista  Plena noite                  Chuva       0
# 3966           Saída de Pista  Plena noite               Ignorada       0
# 6878           Saída de Pista    Pleno dia                  Chuva       0
# 9032  Colisão com objeto fixo    Pleno dia              Ceu Claro       0
#
#       ilesos  feridos
# 270        3        4
# 669        2        0
# 3966       1        0
# 6878       1        0
# ...

# %% [markdown]
# ## 2014

# %%
df_2014 = pd.read_csv("datatran2014.csv", sep=';', low_memory=False)

# %%
df_2014 = df_2014[df_2014['municipio'] == 'MANAUS'].copy()

# %%
df_2014.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2014.head()
# Out:
#       data_inversa dia_semana   br     km               causa_acidente  \
# 1674    2014-01-05    Domingo  174  959.0                       Outras
# 3613    2014-01-08     Quarta  174  896.8  Defeito mecânico em veículo
# 4842    2014-01-09     Quinta  174  960.0                       Outras
# 7337    2014-01-18     Sábado  174  894.0  Desobediência à sinalização
# 10426   2014-01-24      Sexta  319    0.8             Falta de atenção
#
#                   tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 1674             Saída de Pista    Pleno dia                Nublado       0
# 3613   Colisão com objeto móvel    Pleno dia                  Chuva       0
# 4842             Saída de Pista  Plena noite               Ignorada       0
# 7337        Colisão Transversal    Pleno dia                  Chuva       0
# 10426           Colisão lateral    Pleno dia              Ceu Claro       0
#
#        ilesos  feridos
# 1674        0        0
# 3613        2        0
# ...

# %% [markdown]
# ## 2015

# %%
df_2015 = pd.read_csv("datatran2015.csv", sep=';', low_memory=False)

# %%
df_2015 = df_2015[df_2015['municipio'] == 'MANAUS'].copy()

# %%
df_2015.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2015.head()
# Out:
#       data_inversa dia_semana   br      km               causa_acidente  \
# 1001    2015-01-03     Sábado  174   939.0      Velocidade incompatível
# 2027    2015-01-07     Quarta  174  1080.0  Defeito mecânico em veículo
# 7203    2015-01-21     Quarta  174   894.2      Velocidade incompatível
# 7211    2015-01-21     Quarta  319     1.0             Falta de atenção
# 10291   2015-01-17     Sábado  174   928.0                       Outras
#
#              tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 1001        Saída de Pista    Pleno dia              Ceu Claro       2
# 2027              Incêndio    Pleno dia              Ceu Claro       0
# 7203   Colisão Transversal    Anoitecer                  Chuva       0
# 7211      Colisão traseira    Pleno dia              Ceu Claro       0
# 10291       Saída de Pista  Plena noite       Nevoeiro/neblina       0
#
#        ilesos  feridos
# 1001        0        5
# 2027        2        0
# 7203        3        0
# ...

# %% [markdown]
# ## 2016

# %%
df_2016 = pd.read_csv("datatran2016.csv", sep=';', low_memory=False)

# %%
df_2016 = df_2016[df_2016['municipio'] == 'MANAUS'].copy()

# %%
df_2016.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf'], axis=1, inplace=True)

# %%
df_2016.head()
# Out:
#      data_inversa dia_semana   br     km  causa_acidente    tipo_acidente  \
# 3101     13/01/16     Quarta  174    921          Outras   Saída de Pista
# 3610     15/01/16      Sexta  174    957        Dormindo  Colisão frontal
# 3888     16/01/16     Sábado  174    945          Outras  Danos Eventuais
# 4789     17/01/16    Domingo  174    897  Defeito na via      Capotamento
# 7828     31/01/16    Domingo  174  891,9          Outras         Incêndio
#
#        fase_dia condicao_metereologica  mortos  ilesos  feridos
# 3101  Pleno dia                  Chuva       0       1        0
# 3610  Pleno dia              Ceu Claro       0       1        1
# 3888  Pleno dia              Ceu Claro       0       0        1
# 4789  Pleno dia                    Sol       0       1        0
# 7828  Amanhecer              Ceu Claro       0       1        0

# %% [markdown]
# ## 2017

# %%
df_2017 = pd.read_csv("datatran2017.csv", sep=';', low_memory=False)

# %%
df_2017 = df_2017[df_2017['municipio'] == 'MANAUS'].copy()

# %%
df_2017.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf','uop','delegacia','regional','latitude','longitude'], axis=1, inplace=True)

# %%
## a partir de 2017 há mais 5 colunas ['uop','delegacia','regional','latitude','longitude']

# %%
df_2017.head()
# Out:
#      data_inversa    dia_semana     br   km  \
# 3239   2017-01-14        sábado  174.0  904
# 4019   2017-01-18  quarta-feira  174.0  890
# 4395   2017-01-20   sexta-feira  174.0  947
# 6437   2017-01-28        sábado  174.0  914
# 8651   2017-02-07   terça-feira  174.0  949
#
#                                          causa_acidente  \
# 3239                        Falta de Atenção à Condução
# 4019                                 Pista Escorregadia
# 4395  Deficiência ou não Acionamento do Sistema de I...
# 6437      Sinalização da via insuficiente ou inadequada
# 8651           Objeto estático sobre o leito carroçável
#
#                     tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 3239    Saída de leito carroçável  Plena Noite                Nublado       0
# 4019    Saída de leito carroçável    Pleno dia              Céu Claro       0
# 4395  Colisão com objeto estático  Plena Noite               Ignorado       0
# ...

# %% [markdown]
# ## 2018

# %%
df_2018 = pd.read_csv("datatran2018.csv", sep=';', low_memory=False)

# %%
df_2018 = df_2018[df_2018['municipio'] == 'MANAUS'].copy()

# %%
df_2018.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf','uop','delegacia','regional','latitude','longitude'], axis=1, inplace=True)

# %%
df_2018.head()
# Out:
#       data_inversa     dia_semana     br     km               causa_acidente  \
# 678     2018-01-04   quinta-feira  174.0    889       Ultrapassagem Indevida
# 6186    2018-01-29  segunda-feira  174.0  939,1       Ultrapassagem Indevida
# 9113    2018-02-11        domingo  174.0    889           Ingestão de Álcool
# 9434    2018-02-12  segunda-feira  174.0  923,5  Falta de Atenção à Condução
# 10599   2018-02-18        domingo  174.0    912           Ingestão de Álcool
#
#                    tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 678              Colisão frontal  Plena Noite       Nevoeiro/Neblina       0
# 6186   Saída de leito carroçável    Pleno dia                Nublado       0
# 9113                 Capotamento    Pleno dia              Céu Claro       0
# 9434   Atropelamento de Pedestre  Plena Noite              Céu Claro       0
# 10599  Atropelamento de Pedestre  Plena Noite              Céu Claro       0
#
#        ilesos  feridos
# ...

# %% [markdown]
# ## 2019

# %%
df_2019 = pd.read_csv("datatran2019.csv", sep=';', low_memory=False)

# %%
df_2019 = df_2019[df_2019['municipio'] == 'MANAUS'].copy()

# %%
df_2019.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf','uop','delegacia','regional','latitude','longitude'], axis=1, inplace=True)

# %%
df_2019.head()
# Out:
#      data_inversa    dia_semana     br     km                causa_acidente  \
# 60     2019-01-01   terça-feira  174.0    938            Ingestão de Álcool
# 2425   2019-01-16  quarta-feira  174.0  894,3  Falta de Atenção do Pedestre
# 2589   2019-01-17  quinta-feira  174.0    980   Falta de Atenção à Condução
# 4223   2019-01-27       domingo  174.0    937   Falta de Atenção à Condução
# 9713   2019-02-28  quinta-feira  174.0    901   Falta de Atenção à Condução
#
#                   tipo_acidente     fase_dia condicao_metereologica  mortos  \
# 60    Saída de leito carroçável    Pleno dia              Céu Claro       0
# 2425  Atropelamento de Pedestre  Plena Noite              Céu Claro       1
# 2589           Colisão traseira    Pleno dia               Ignorado       0
# 4223  Saída de leito carroçável    Pleno dia                  Chuva       0
# 9713  Saída de leito carroçável    Pleno dia                Nublado       0
#
#       ilesos  feridos
# 60         1        0
# ...

# %% [markdown]
# ## 2020

# %%
df_2020 = pd.read_csv("datatran2020.csv", sep=';', low_memory=False)

# %%
df_2020 = df_2020[df_2020['municipio'] == 'MANAUS'].copy()

# %%
df_2020.drop(['id','uso_solo','sentido_via','tipo_pista','tracado_via','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente','municipio','uf','uop','delegacia','regional','latitude','longitude'], axis=1, inplace=True)

# %%
df_2020.head()
# Out:
#       data_inversa    dia_semana     br     km  \
# 839     2020-01-05       domingo  174.0    972
# 2468    2020-01-15  quarta-feira  174.0  924,9
# 6004    2020-02-04   terça-feira  174.0  972,1
# 7423    2020-02-02       domingo  174.0    900
# 10400   2020-02-23       domingo  174.0  913,1
#
#                                           causa_acidente  \
# 839                          Defeito Mecânico no Veículo
# 2468                         Falta de Atenção à Condução
# 6004                         Falta de Atenção à Condução
# 7423   Desobediência às normas de trânsito pelo condutor
# 10400                                 Ingestão de Álcool
#
#                      tipo_acidente   fase_dia condicao_metereologica  mortos  \
# 839      Saída de leito carroçável  Pleno dia                    Sol       0
# 2468     Saída de leito carroçável  Pleno dia              Céu Claro       1
# 6004     Saída de leito carroçável  Anoitecer              Céu Claro       0
# ...

# %% [markdown]
# ## Criando o Dataframe Manaus

# %%
df_manaus = pd.DataFrame()

# %%
df_manaus = pd.concat([df_2007, df_2008, df_2009,df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020])

# %%
df_manaus.reset_index(inplace=True, drop=True)

# %%
df_manaus.head()
# Out:
#   data_inversa dia_semana   br    km    causa_acidente     tipo_acidente  \
# 0   02/01/2007      Terça  174   9.3  Falta de atenção    Saída de Pista
# 1   02/01/2007      Terça  174   7.9            Outras  Colisão traseira
# 2   07/01/2007    Domingo  174  52.1    Defeito na via       Capotamento
# 3   11/01/2007     Quinta  174  85.8            Outras          Incêndio
# 4   19/01/2007      Sexta  174   3.3  Falta de atenção   Colisão lateral
#
#     fase_dia condicao_metereologica  mortos  ilesos  feridos
# 0  Pleno dia                  Chuva       0       0        1
# 1  Anoitecer                  Chuva       0       4        0
# 2  Pleno dia                    Sol       0       0        2
# 3  Anoitecer       Nevoeiro/neblina       0       1        0
# 4  Pleno dia              Ceu Claro       0       2        0

# %%
plt.figure(figsize=(20,10))
df_manaus.feridos.plot()
plt.show()

# %%
df_manaus.feridos.max()
# Out:
# 14

# %%
df_manaus[df_manaus.feridos == 14]
# Out:
#     data_inversa dia_semana   br km           causa_acidente    tipo_acidente  \
# 167   07/05/2008     Quarta  174  2  Velocidade incompatível  Colisão frontal
#
#       fase_dia condicao_metereologica  mortos  ilesos  feridos
# 167  Pleno dia                  Chuva       3       2       14

# %%
df_manaus.to_csv("2007_2020_Manaus.csv", sep=";", index=False)
