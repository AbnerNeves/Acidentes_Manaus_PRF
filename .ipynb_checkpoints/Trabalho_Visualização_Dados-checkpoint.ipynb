# %% [markdown]
# oq entendi kkk
# TRABALHO DE VISUALIZAÇÃO DE DADOS
#
# . APRESENTAÇÃO DA EQUIPE
#
# . APRESENTAÇÃO DO DATASET UITILIZADO
#
# . DESCREVENDO O PROBLEMA Ex.: O Rank dos 10 melhores países por produto
#
# . DESCREVENDO A SOLUÇÃO
# 	- Comparação
# 	- Relacionamento
# 	- Distribuição
# 	- Composição
#
# 	Implementar todos os gráficos ensinados na aula, porém apresentar apenas o que melhor se encaixa na solução.
# qualquer coisa não fui eu!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from os import listdir
from os.path import isfile, join

# %%
files = [f for f in listdir(os.getcwd()) if isfile(join(os.getcwd(), f))]
files
# Out:
# ['.gitattributes',
#  'datatran2007.csv',
#  'datatran2008.csv',
#  'datatran2009.csv',
#  'datatran2010.csv',
#  'datatran2011.csv',
#  'datatran2012.csv',
#  'datatran2013.csv',
#  'datatran2014.csv',
#  'datatran2015.csv',
#  'datatran2016_atual.csv',
#  'datatran2017.csv',
#  'datatran2018.csv',
#  'datatran2019.csv',
#  'datatran2020.csv',
#  'LICENSE',
#  'README.md',
#  'Trabalho_Visualização_Dados.ipynb']

# %%
df_2007 = pd.read_csv("datatran2007.csv", sep=';', low_memory=False)

# %%
df_2007.head()
# Out:
#         id data_inversa dia_semana   horario  uf   br     km  municipio  \
# 0       10   11/06/2007    Segunda  15:30:00  MG  381  623.2   OLIVEIRA
# 1       10   11/06/2007    Segunda  15:30:00  MG  381  623.2   OLIVEIRA
# 2  1032898   13/08/2007    Segunda  14:25:00  MG   40  585.5  ITABIRITO
# 3  1051130   12/02/2007    Segunda  02:10:00  MA  135     11   SAO LUIS
# 4  1066824   20/11/2007      Terça  05:30:00  CE  222   30.8    CAUCAIA
#
#                 causa_acidente            tipo_acidente  ... uso_solo   ano  \
# 0             Falta de atenção          Colisão frontal  ...    Rural  2007
# 1             Falta de atenção          Colisão frontal  ...    Rural  2007
# 2                       Outras           Saída de Pista  ...    Rural  2007
# 3             Animais na Pista  Atropelamento de animal  ...   Urbano  2007
# 4  Defeito mecânico em veículo              Capotamento  ...    Rural  2007
#
#   pessoas mortos feridos_leves feridos_graves ilesos  ignorados  feridos  \
# ...

# %%
df_2007.drop(['id','uf','uso_solo','municipio','sentido_via','tipo_pista','tracado_via','ano','ignorados','horario','pessoas','veiculos','feridos_leves','feridos_graves','classificacao_acidente'], axis=1, inplace=True)

# %%
df_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127675 entries, 0 to 127674
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   data_inversa            127675 non-null  object
#  1   dia_semana              127675 non-null  object
#  2   br                      127675 non-null  object
#  3   km                      127675 non-null  object
#  4   causa_acidente          127675 non-null  object
#  5   tipo_acidente           127675 non-null  object
#  6   fase_dia                127675 non-null  object
#  7   condicao_metereologica  127675 non-null  object
#  8   mortos                  127675 non-null  int64
#  9   ilesos                  127675 non-null  int64
#  10  feridos                 127675 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 10.7+ MB

# %%
df_2007
# Out:
#        data_inversa dia_semana   br     km               causa_acidente  \
# 0        11/06/2007    Segunda  381  623.2             Falta de atenção
# 1        11/06/2007    Segunda  381  623.2             Falta de atenção
# 2        13/08/2007    Segunda   40  585.5                       Outras
# 3        12/02/2007    Segunda  135     11             Animais na Pista
# 4        20/11/2007      Terça  222   30.8  Defeito mecânico em veículo
# ...             ...        ...  ...    ...                          ...
# 127670   15/12/2007     Sábado   50     22             Falta de atenção
# 127671   16/06/2007     Sábado  373  268.3                       Outras
# 127672   11/12/2007      Terça   70  697.1                       Outras
# 127673   09/05/2007     Quarta  470   65.8             Falta de atenção
# 127674   07/02/2007     Quarta  324  603.5             Falta de atenção
#
#                   tipo_acidente     fase_dia condicao_metereologica  mortos  \
# ...

# %%
df_manaus = df_2007[df_2007['municipio'] == 'MANAUS'].copy()
df_manaus
# Out:
#             id data_inversa dia_semana   horario  uf   br    km municipio  \
# 1112    175459   02/01/2007      Terça  16:00:00  AM  174   9.3    MANAUS
# 1145    175497   02/01/2007      Terça  19:00:00  AM  174   7.9    MANAUS
# 1964    176564   07/01/2007    Domingo  16:50:00  AM  174  52.1    MANAUS
# 2931    177902   11/01/2007     Quinta  03:00:00  AM  174  85.8    MANAUS
# 5475    181241   19/01/2007      Sexta  06:50:00  AM  174   3.3    MANAUS
# ...        ...          ...        ...       ...  ..  ...   ...       ...
# 123890  321582   21/12/2007      Sexta  20:50:00  AM  319   0.6    MANAUS
# 125347  323164   29/12/2007     Sábado  19:00:00  AM  174     8    MANAUS
# 125970  323808   31/12/2007    Segunda  16:50:00  AM  174    57    MANAUS
# 126836  336005   02/04/2007    Segunda  17:00:00  AM  174    41    MANAUS
# 126909  341246   28/04/2007     Sábado  00:30:00  AM  174  35.2    MANAUS
#
#             causa_acidente     tipo_acidente  ... uso_solo   ano pessoas  \
# ...

# %%
df_manaus.columns

# %%
df_manaus.drop(['id','uf','uso_solo','municipio','sentido_via','tipo_pista','tracado_via','ano','ignorados'], axis=1, inplace=True)

# %%
df_manaus
# Out:
#        data_inversa dia_semana   horario   br    km      causa_acidente  \
# 1112     02/01/2007      Terça  16:00:00  174   9.3    Falta de atenção
# 1145     02/01/2007      Terça  19:00:00  174   7.9              Outras
# 1964     07/01/2007    Domingo  16:50:00  174  52.1      Defeito na via
# 2931     11/01/2007     Quinta  03:00:00  174  85.8              Outras
# 5475     19/01/2007      Sexta  06:50:00  174   3.3    Falta de atenção
# ...             ...        ...       ...  ...   ...                 ...
# 123890   21/12/2007      Sexta  20:50:00  319   0.6  Ingestão de álcool
# 125347   29/12/2007     Sábado  19:00:00  174     8    Falta de atenção
# 125970   31/12/2007    Segunda  16:50:00  174    57    Falta de atenção
# 126836   02/04/2007    Segunda  17:00:00  174    41  Ingestão de álcool
# 126909   28/04/2007     Sábado  00:30:00  174  35.2              Outras
#
#            tipo_acidente classificacao_acidente     fase_dia  \
# ...

# %%
df_manaus.info()

# %%
df_manaus['data_inversa'] = df_manaus['data_inversa'].astype('datetime64[ns, US/Eastern]')

# %%
df_manaus
